# %% [markdown]
# ### 🔹 Roadmap
#
#
#
# ## ✅ STEP 1: Requirements & Roles (Foundation)
#
# **Goal:** Clearly define *who* uses the system and *what* they can do.
#
# ### Roles (fixed for now)
#
# 1. **Student**
# 2. **Faculty**
# 3. **Administrator**
#
# ### Responsibilities
#
# * **Student**
#
#   * View profile
#   * View enrolled courses
#   * View attendance
#   * View results
#
# * **Faculty**
#
#   * View assigned courses
#   * Mark attendance
#   * Upload marks
#
# * **Administrator**
#
#   * Manage users
#   * Manage roles
#   * Create courses
#   * Assign faculty
#   * View all data
#
# 👉 Output of Step 1: **Confirmed system scope**
#
# ---
#
# ## ⏭️ STEP 2: Identify Entities & Attributes
#
# **Goal:** Decide what tables are required.
#
# Main entities:
#
# * Users
# * Roles
# * Students
# * Faculty
# * Courses
# * Enrollments
# * Attendance
# * Results
#
# 👉 Output: **List of tables + attributes**
#
# ---
#
# ## ⏭️ STEP 3: ER Diagram
#
# **Goal:** Visual representation of relationships.
#
# * One user → one role
# * Student ↔ Courses (many-to-many)
# * Faculty → Courses (one-to-many)
#
# 👉 Output: **ER diagram (exam-ready)**
#
# ---
#
# ## ⏭️ STEP 4: Normalization
#
# **Goal:** Remove redundancy.
#
# * 1NF → atomic fields
# * 2NF → no partial dependency
# * 3NF → no transitive dependency
#
# 👉 Output: **Normalized schema**
#
# ---
#
# ## ⏭️ STEP 5: SQL Implementation
#
# **Goal:** Convert design into SQL.
#
# * `CREATE TABLE`
# * Primary & foreign keys
# * Constraints
#
# 👉 Output: **Executable SQL script**
#
# ---
#
# ## ⏭️ STEP 6: Sample Data & Queries
#
# **Goal:** Make it testable.
#
# * Insert dummy users
# * Role-based queries
# * Admin / Student / Faculty queries
#
# 👉 Output: **Working queries**
#
# ---
#
# ## ⏭️ STEP 7: Access Control Logic (Conceptual)
#
# **Goal:** Show how roles restrict access.
#
# * RBAC tables
# * Permission mapping
# * Login flow explanation
#
# 👉 Output: **Interview-ready explanation**
#
# ---
#
# ### 🎯 Why This Approach Works
#
# * Easy to explain in **DBMS viva**
# * Perfect for **college submission**
# * Strong **portfolio project**
# * Can grow into full-stack anytime
#
# ---

# %% [markdown]
# ## 🔷 STEP 2: Identify Entities & Attributes
#
# Below is the **clean, normalized entity list** we’ll use. This is exam-safe, real-world, and scalable.
#
# ---
#
# ### 1️⃣ `roles`
#
# | Field        | Description               |
# | ------------ | ------------------------- |
# | role_id (PK) | Unique role ID            |
# | role_name    | student / faculty / admin |
#
# ---
#
# ### 2️⃣ `users`
#
# | Field         | Description        |
# | ------------- | ------------------ |
# | user_id (PK)  | Unique user        |
# | name          | Full name          |
# | email         | Login email        |
# | password_hash | Encrypted password |
# | role_id (FK)  | Role reference     |
# | status        | active / inactive  |
# | created_at    | Account creation   |
#
# ---
#
# ### 3️⃣ `students`
#
# | Field           | Description      |
# | --------------- | ---------------- |
# | student_id (PK) | Student ID       |
# | user_id (FK)    | Links to users   |
# | roll_no         | University roll  |
# | department      | CSE, ECE, etc.   |
# | semester        | Current semester |
# | admission_year  | Year of joining  |
#
# ---
#
# ### 4️⃣ `faculty`
#
# | Field           | Description          |
# | --------------- | -------------------- |
# | faculty_id (PK) | Faculty ID           |
# | user_id (FK)    | Links to users       |
# | department      | Teaching dept        |
# | designation     | Professor, Asst Prof |
#
# ---
#
# ### 5️⃣ `courses`
#
# | Field           | Description      |
# | --------------- | ---------------- |
# | course_id (PK)  | Course ID        |
# | course_name     | DBMS, OS         |
# | faculty_id (FK) | Course owner     |
# | semester        | Offered semester |
# | credits         | Credit points    |
#
# ---
#
# ### 6️⃣ `enrollments`
#
# *(Resolves many-to-many between students & courses)*
#
# | Field              | Description  |
# | ------------------ | ------------ |
# | enrollment_id (PK) | Unique entry |
# | student_id (FK)    | Student      |
# | course_id (FK)     | Course       |
#
# ---
#
# ### 7️⃣ `attendance`
#
# | Field              | Description      |
# | ------------------ | ---------------- |
# | attendance_id (PK) | Attendance ID    |
# | student_id (FK)    | Student          |
# | course_id (FK)     | Course           |
# | date               | Lecture date     |
# | status             | Present / Absent |
#
# ---
#
# ### 8️⃣ `results`
#
# | Field           | Description |
# | --------------- | ----------- |
# | result_id (PK)  | Result ID   |
# | student_id (FK) | Student     |
# | course_id (FK)  | Course      |
# | marks           | Score       |
# | grade           | A, B, C     |
#
# ---
#
# ## 🔐 (Reserved for Later Step)
#
# We’ll add:
#
# * `permissions`
# * `role_permissions`
#
# when we reach **STEP 7 (RBAC Logic)**.
#
# ---
#
# ## ✔️ Output of STEP 2
#
# * Final list of tables ✅
# * Attributes finalized ✅
# * Ready for ER diagram ✅
#
# ---

# %% [markdown]
# ## 🔷 STEP 3: ER Diagram (University Management System)
#
# ### 📌 Entities Involved
#
# * Users
# * Roles
# * Students
# * Faculty
# * Courses
# * Enrollments
# * Attendance
# * Results
#
# ---
#
# ## 🔗 Relationships & Cardinality (VERY IMPORTANT)
#
# ### 1️⃣ Roles → Users
#
# * **One role** can be assigned to **many users**
# * **Each user** has **exactly one role**
#
# ```
# Role (1) ──────── (M) Users
# ```
#
# ---
#
# ### 2️⃣ Users → Students / Faculty
#
# * One user is **either a student or faculty**
# * Admin exists **only in users table**
#
# ```
# Users (1) ─── (1) Students
# Users (1) ─── (1) Faculty
# ```
#
# ---
#
# ### 3️⃣ Faculty → Courses
#
# * One faculty can teach **many courses**
# * Each course is taught by **one faculty**
#
# ```
# Faculty (1) ──────── (M) Courses
# ```
#
# ---
#
# ### 4️⃣ Students ↔ Courses (via Enrollments)
#
# * Many students enroll in many courses
#
# ```
# Students (M) ── (M) Courses
#         │
#         └── Enrollments
# ```
#
# ---
#
# ### 5️⃣ Attendance
#
# * Each attendance record belongs to:
#
#   * One student
#   * One course
#
# ```
# Students (1) ─── (M) Attendance (M) ─── (1) Courses
# ```
#
# ---
#
# ### 6️⃣ Results
#
# * One student gets **one result per course**
#
# ```
# Students (1) ─── (M) Results (M) ─── (1) Courses
# ```
#
# ---
#
# ## 🖼️ ER Diagram (Visual Reference)
#
# ![Image](https://images.wondershare.com/edrawmax/templates/er-diagram-for-university-management.png)
#
# ![Image](https://www.researchgate.net/profile/Alexander-Hayes/publication/321890328/figure/fig2/AS%3A713595977482248%401547145947957/An-ER-Diagram-illustrating-3-entities-Professors-Students-and-Courses-their_Q320.jpg)
#
# ![Image](https://i.sstatic.net/Vyqaa.jpg)
#
# *(We’ll draw a clean custom diagram later if needed for submission.)*
#
# ---
#
# ## 📘 ER Diagram – Exam Explanation (You Can Say This)
#
# > “The ER diagram consists of entities like Users, Roles, Students, Faculty, Courses, Enrollments, Attendance, and Results.
# > Users are linked with roles to implement role-based access.
# > Students and courses have a many-to-many relationship resolved using the Enrollments table.
# > Attendance and Results store academic records and depend on both students and courses.”
#
# ---
#
# ## ✔️ STEP 3 — LOCKED
#
# * Relationships finalized ✅
# * Cardinality clear ✅
# * Ready for normalization ✅
#
# ---

# %% [markdown]
# Awesome — we’re building this **properly and cleanly** 💪
# Now we make your design **theoretically strong**.
#
# ---
#
# ## 🔷 STEP 4: Normalization (1NF → 3NF)
#
# Normalization ensures:
#
# * No redundancy
# * No update anomalies
# * Clean relational structure
#
# We’ll verify each normal form using **your current schema**.
#
# ---
#
# ## ✅ First Normal Form (1NF)
#
# ### Rule
#
# * Atomic values (no multivalued fields)
# * No repeating groups
# * Unique rows (primary key)
#
# ### ✔️ Applied in Our Design
#
# * `users.email` → single value
# * `courses.course_name` → single value
# * No columns like `subjects = DBMS, OS`
#
# ✔️ **All tables satisfy 1NF**
#
# ---
#
# ## ✅ Second Normal Form (2NF)
#
# ### Rule
#
# * Must be in 1NF
# * No partial dependency on composite keys
#
# ### ✔️ Applied in Our Design
#
# * Composite relationships (Student–Course) handled using:
#
#   * `enrollments(enrollment_id)`
#   * `attendance(attendance_id)`
# * No non-key attribute depends on part of a composite key
#
# ✔️ **All tables satisfy 2NF**
#
# ---
#
# ## ✅ Third Normal Form (3NF)
#
# ### Rule
#
# * Must be in 2NF
# * No transitive dependency
#   *(Non-key attribute should not depend on another non-key attribute)*
#
# ### ✔️ Applied in Our Design
#
# * Role information stored in `roles`, not in `users`
# * Faculty details not stored in `courses`
# * Student personal data not repeated in results or attendance
#
# ✔️ **All tables satisfy 3NF**
#
# ---
#
# ## 📌 Example (Why This Matters)
#
# ❌ **Bad Design**
#
# ```text
# students(roll_no, name, course_name, faculty_name)
# ```
#
# ✔️ **Our Design**
#
# ```text
# students → enrollments → courses → faculty
# ```
#
# This avoids:
#
# * Update anomaly
# * Insert anomaly
# * Delete anomaly
#
# ---
#
# ## 📘 Viva-Ready Explanation
#
# > “The database is normalized up to Third Normal Form.
# > All attributes are atomic, partial dependencies are removed using junction tables, and transitive dependencies are eliminated by separating roles, users, and academic entities into independent tables.”
#
# ---
#
# ## ✔️ STEP 4 — LOCKED
#
# * Normal forms proven ✅
# * DBMS theory covered ✅
# * Ready for SQL implementation ✅
#
# ---
