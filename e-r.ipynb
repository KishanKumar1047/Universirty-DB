# %% [markdown]
# ## 📘 FINAL ER DIAGRAM
#
# **University Management System with RBAC**
#
# ![Image](https://images.wondershare.com/edrawmax/templates/er-diagram-for-university-management.png)
#
# ![Image](https://miro.medium.com/1%2AjnG2OLB8Zc9DveIfbx9vRw.png)
#
# ![Image](https://www.darwinbiler.com/assets/RBAC-New-Page.png)
#
# ![Image](https://i.sstatic.net/TXux1.png)
#
# ---
#
# ## 🧩 ENTITIES & ATTRIBUTES (Final)
#
# ### 🔹 Role
#
# * **role_id (PK)**
# * role_name
#
# ---
#
# ### 🔹 User
#
# * **user_id (PK)**
# * name
# * email
# * password_hash
# * status
# * created_at
# * **role_id (FK)**
#
# ---
#
# ### 🔹 Student
#
# * **student_id (PK)**
# * roll_no
# * department
# * semester
# * admission_year
# * **user_id (FK)**
#
# ---
#
# ### 🔹 Faculty
#
# * **faculty_id (PK)**
# * department
# * designation
# * **user_id (FK)**
#
# ---
#
# ### 🔹 Course
#
# * **course_id (PK)**
# * course_name
# * semester
# * credits
# * **faculty_id (FK)**
#
# ---
#
# ### 🔹 Enrollment
#
# * **enrollment_id (PK)**
# * **student_id (FK)**
# * **course_id (FK)**
#
# ---
#
# ### 🔹 Attendance
#
# * **attendance_id (PK)**
# * date
# * status
# * **student_id (FK)**
# * **course_id (FK)**
#
# ---
#
# ### 🔹 Result
#
# * **result_id (PK)**
# * marks
# * grade
# * **student_id (FK)**
# * **course_id (FK)**
#
# ---
#
# ### 🔹 Permission
#
# * **permission_id (PK)**
# * permission_name
#
# ---
#
# ### 🔹 Role_Permission
#
# * **role_id (FK)**
# * **permission_id (FK)**
#
# ---
#
# ## 🔗 RELATIONSHIPS & CARDINALITY (MOST IMPORTANT)
#
# ```
# Role (1) ───────── (M) User
#
# User (1) ─── (1) Student
# User (1) ─── (1) Faculty
#
# Faculty (1) ───────── (M) Course
#
# Student (M) ─── (M) Course
#         │
#         └── Enrollment
#
# Student (1) ───────── (M) Attendance
# Course  (1) ───────── (M) Attendance
#
# Student (1) ───────── (M) Result
# Course  (1) ───────── (M) Result
#
# Role (M) ─── (M) Permission
#         │
#         └── Role_Permission
# ```
#
# ---
#
# ## ✍️ HOW TO DRAW THIS IN EXAM / RECORD
#
# **Steps to draw clean ER diagram:**
#
# 1. Draw rectangles for all entities
# 2. Underline primary keys
# 3. Mark foreign keys
# 4. Use diamonds / lines for relationships
# 5. Show cardinality (1, M)
#
# ---
#
# ## 🧠 VIVA-FRIENDLY EXPLANATION (YOU CAN MEMORIZE)
#
# > “This ER diagram represents a university management system with role-based access control.
# > Users are assigned roles, and roles are mapped to permissions using a many-to-many relationship.
# > Students and courses have a many-to-many relationship resolved through the enrollment entity.
# > Attendance and results depend on both students and courses.
# > The design is normalized up to third normal form and ensures data integrity and security.”
#
# ---
#
# ## ✅ FINAL STATUS
#
# ✔️ ER Diagram — **DONE**
# ✔️ Schema — **DONE**
# ✔️ RBAC — **DONE**
# ✔️ SQL — **DONE**
